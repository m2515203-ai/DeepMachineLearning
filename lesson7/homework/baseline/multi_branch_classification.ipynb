# %% [markdown]
# # Домашнее задание: Multi-Branch MLP для Wine Quality
#
# **Цель**: Реализовать multi-branch модель и добиться F1 score ≥ 40%
#
# **Задачи**:
# 1. Реализовать три типа блоков: Bottleneck, Inverted Bottleneck, Regular
# 2. Создать Multi-Branch архитектуру
# 3. Использовать weighted loss для борьбы с дисбалансом классов
# 4. Подобрать оптимальные гиперпараметры (глубина, ширина, lr, оптимизатор)

# %%
import os

import pylab as pl
from lightning_fabric.loggers import CSVLogger
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping

from lesson7.homework.baseline.data_module import DataModule

os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

import warnings
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.utils.class_weight import compute_class_weight
import sys
sys.path.append('../../../lesson3/seminar')
from lesson3.seminar.wine_quality_data import WineQualityDataModule
from lesson3.seminar.lightning_module import BaseLightningModule
from lesson3.seminar.utils import set_seed
from pytorch_lightning import Trainer
import torch
import torch.nn as nn
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import CSVLogger
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
set_seed(42)
import torch
print(torch.cuda.is_available())
max_epochs = 20
torch.set_float32_matmul_precision("medium")
# Out:
# True

# %% [markdown]
# ## 1. Загрузка и анализ данных
#
# Загрузим Wine Quality датасет и проанализируем распределение классов.

# %%
data_dir = '../data'

dm = DataModule(
    data_dir=data_dir,
    batch_size=128,
    num_workers=4
)

dm.setup()

print(f'Input dimension: {dm.input_dim}')
print(f'Number of classes: {dm.n_classes}')
print(f'Labeled train samples: {len(dm.train_labeled_dataset)}')
print(f'Test samples: {len(dm.test_dataset)}')
# Out:
# Input dimension: 3072
# Number of classes: 10
# Labeled train samples: 1600
# Test samples: 4000
# Input dimension: 3072
# Number of classes: 10
# Labeled train samples: 1600
# Test samples: 4000

# %% [markdown]
# ### 1.1. Анализ дисбаланса классов
#
# Проанализируйте распределение классов и вычислите веса для weighted loss.

# %%
train_labels = []
for i in range(len(dm.train_labeled_dataset)):
    _, yi = dm.train_labeled_dataset[i]
    train_labels.append(int(yi))
train_labels = np.array(train_labels)


plt.figure(figsize=(6, 4))
plt.hist(train_labels, bins=np.arange(dm.n_classes + 1) - 0.5, rwidth=0.8)
plt.xticks(range(dm.n_classes))
plt.xlabel('Class index')
plt.ylabel('Frequency')
plt.title('Distribution of training classes')
plt.show()


class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(dm.n_classes),
    y=train_labels
)

print(f'Class weights: {class_weights}')
# Out:
# Class weights: [1.0738255  0.96385542 1.02564103 1.10344828 0.95238095 0.93567251
#  0.95238095 1.05960265 0.92485549 1.04575163]

# %% [markdown]
# ## 2. Реализация блоков
#
# Реализуйте три типа блоков:
# - **Bottleneck**: dim → dim//4 → dim (сужение)
# - **Inverted Bottleneck**: dim → dim*4 → dim (расширение)
# - **Regular**: dim → hidden_dim → dim (обычный)

# %%
from abc import ABC, abstractmethod

class BaseMLPBlock(nn.Module, ABC):
    """Базовый класс для MLP блока"""
    def __init__(self, dim, activation='gelu', dropout=0.0):
        super().__init__()
        self.dim = dim
        self.activation = {'relu': nn.ReLU(), 'gelu': nn.GELU(), 'swish': nn.SiLU()}.get(activation, nn.GELU())
        self.dropout = nn.Dropout(dropout) if dropout > 0 else None
    
    @abstractmethod
    def forward(self, x):
        pass

class BottleneckBlock(BaseMLPBlock):
    """
    Bottleneck блок: dim → dim//4 → dim
    
    Сужает размерность в 4 раза, затем восстанавливает.
    Использует residual connection для стабильного обучения.
    """
    def __init__(self, dim, activation='gelu', dropout=0.0):
        super().__init__(dim, activation, dropout)
        
        # Bottleneck dimension (сужение в 4 раза)
        self.bottleneck_dim = max(dim // 4, 1)
        
        # Линейные слои: dim → bottleneck_dim → dim
        self.fc1 = nn.Linear(self.dim, self.bottleneck_dim)
        self.fc2 = nn.Linear(self.bottleneck_dim, self.dim)
    
    def forward(self, x):
        identity = x
        
        # Bottleneck pathway
        out = self.fc1(x)
        out = self.activation(out)
        if self.dropout:
            out = self.dropout(out)
        out = self.fc2(out)
        
        # Residual connection
        return out + identity

class InvertedBottleneckBlock(BaseMLPBlock):
    """
    Inverted Bottleneck блок: dim → dim*4 → dim
    
    Расширяет размерность в 4 раза, затем сжимает обратно.
    Использует residual connection для стабильного обучения.
    """
    def __init__(self, dim, expansion_factor=4, activation='gelu', dropout=0.0):
        super().__init__(dim, activation, dropout)
        
        # Expanded dimension (расширение в 4 раза)
        self.expanded_dim = dim * expansion_factor
        
        # Линейные слои: dim → expanded_dim → dim
        self.fc1 = nn.Linear(self.dim, self.expanded_dim)
        self.fc2 = nn.Linear(self.expanded_dim, self.dim)
    
    def forward(self, x):
        identity = x
        
        # Inverted bottleneck pathway
        out = self.fc1(x)
        out = self.activation(out)
        if self.dropout:
            out = self.dropout(out)
        out = self.fc2(out)
        
        # Residual connection
        return out + identity

class RegularBlock(BaseMLPBlock):
    """
    Regular блок: dim → hidden_dim → dim
    
    Обычный двухслойный MLP с residual connection.
    hidden_dim по умолчанию равен dim * 2.
    """
    def __init__(self, dim, hidden_dim=None, activation='gelu', dropout=0.0):
        super().__init__(dim, activation, dropout)
        
        # Hidden dimension (по умолчанию в 2 раза больше)
        self.hidden_dim = hidden_dim if hidden_dim else dim * 2

        # Линейные слои: dim → hidden_dim → dim
        self.fc1 = nn.Linear(self.dim, self.hidden_dim)
        self.fc2 = nn.Linear(self.hidden_dim, self.dim)
    
    def forward(self, x):
        identity = x
        
        # Regular pathway
        out = self.fc1(x)
        out = self.activation(out)
        if self.dropout:
            out = self.dropout(out)
        out = self.fc2(out)
        
        # Residual connection
        return out + identity

# Тестируем блоки
print('✓ Блоки успешно определены!')
print()

# Проверим размерности
test_x = torch.randn(4, 64)
print('Тестирование блоков с размерностью 64:')
print(f'  Input shape: {test_x.shape}')

bottleneck = BottleneckBlock(64)
print(f'  BottleneckBlock output: {bottleneck(test_x).shape}')

inverted = InvertedBottleneckBlock(64)
print(f'  InvertedBottleneckBlock output: {inverted(test_x).shape}')

regular = RegularBlock(64)
print(f'  RegularBlock output: {regular(test_x).shape}')

# Подсчитаем параметры
print()
print('Количество параметров:')
print(f'  BottleneckBlock: {sum(p.numel() for p in bottleneck.parameters()):,}')
print(f'  InvertedBottleneckBlock: {sum(p.numel() for p in inverted.parameters()):,}')
print(f'  RegularBlock: {sum(p.numel() for p in regular.parameters()):,}')
# Out:
# ✓ Блоки успешно определены!
#
# Тестирование блоков с размерностью 64:
#   Input shape: torch.Size([4, 64])
#   BottleneckBlock output: torch.Size([4, 64])
#   InvertedBottleneckBlock output: torch.Size([4, 64])
#   RegularBlock output: torch.Size([4, 64])
#
# Количество параметров:
#   BottleneckBlock: 2,128
#   InvertedBottleneckBlock: 33,088
#   RegularBlock: 16,576

# %% [markdown]
# ## 3. Multi-Branch модель
#
# Реализуйте модель с тремя параллельными ветками.
#
# **Архитектура**:
# ```
#          Input
#            |
#       projection
#            |
#       ┌────┼────┐
#       │    │    │
#   Bottleneck  Inverted  Regular
#    Branch      Branch    Branch
#       │    │    │
#       └────┼────┘
#            |
#       Concatenate/Sum
#            |
#       projection
#            |
#         Output
# ```

# %%
class MultiBranchMLP(nn.Module):
    """
    Multi-Branch MLP с тремя параллельными ветками.
    
    Args:
        input_dim: размерность входа
        hidden_dim: размерность скрытых слоев
        output_dim: размерность выхода (число классов)
        num_blocks: количество блоков в каждой ветке
        dropout: вероятность dropout
        combine_mode: способ объединения веток ('concat' или 'sum')
    """
    def __init__(
        self,
        input_dim,
        hidden_dim,
        output_dim,
        num_blocks=4,
        dropout=0.1,
        combine_mode='concat',
        activation='gelu'
    ):
        super().__init__()
        self.output_dim = output_dim
        self.combine_mode = combine_mode

        # Входная проекция
        self.input_proj = nn.Linear(input_dim, hidden_dim)

        # Три ветви: Bottleneck, Inverted Bottleneck и Regular
        self.bottleneck_branch = nn.ModuleList([
            BottleneckBlock(hidden_dim, dropout=dropout,activation=activation) for _ in range(num_blocks)
        ])
        self.inverted_branch = nn.ModuleList([
            InvertedBottleneckBlock(hidden_dim, dropout=dropout,activation=activation) for _ in range(num_blocks)
        ])
        self.regular_branch = nn.ModuleList([
            RegularBlock(hidden_dim, dropout=dropout,activation=activation) for _ in range(num_blocks)
        ])


        class ResidualMLPBlock(nn.Module):
            def __init__(self, dim: int, dropout: float = 0.1):
                super().__init__()
                self.block = nn.Sequential(
                nn.Linear(dim, dim),
                nn.BatchNorm1d(dim),
                nn.ReLU(),
                nn.Dropout(dropout)
                )


            def forward(self, x):
                return x + self.block(x)
        self.shared_blocks = nn.Sequential(*[ResidualMLPBlock(hidden_dim, dropout=0.1) for _ in range(num_blocks)]
)

        # Выходная проекция.  Для concat вход равен hidden_dim*3, для sum — hidden_dim
        combined_dim = hidden_dim * 3 if combine_mode == 'concat' else hidden_dim
        self.output_proj = nn.Linear(combined_dim, output_dim)

    def forward(self, x):
        # Входная проекция
        x = self.input_proj(x)
        # Bottleneck ветка
        out_bottleneck = x
        for block in self.bottleneck_branch:
            out_bottleneck = block(out_bottleneck)
        # Inverted Bottleneck ветка
        out_inverted = x
        for block in self.inverted_branch:
            out_inverted = block(out_inverted)
        # Regular ветка
        out_regular = x
        for block in self.regular_branch:
            out_regular = block(out_regular)
        # Объединение результатов
        if self.combine_mode == 'concat':
            out = torch.cat([out_bottleneck, out_inverted, out_regular], dim=-1)
        else:
            out = out_bottleneck + out_inverted + out_regular
        # Выходная проекция
        logits = self.output_proj(out)
        return logits

print('Multi-Branch модель определена!')
# Out:
# Multi-Branch модель определена!

# %% [markdown]
# ## 4. Код обучение

# %% [markdown]
# ## 5. Итоговая модель
#
# Обучите модель с лучшими гиперпараметрами.

# %%
from pytorch_lightning.profilers import SimpleProfiler


def train_model(
    model,
    dm,
    class_weights=None,
    max_epochs=max_epochs,
    lr=1e-3,
    optimizer_type='adam'
):
    if class_weights is not None:
        weight_tensor = torch.tensor(class_weights, dtype=torch.float32)
        loss_fn = nn.CrossEntropyLoss(weight=weight_tensor)
    else:
        loss_fn = nn.CrossEntropyLoss()

    lightning_model = BaseLightningModule(
        model=model,
        loss_fn=loss_fn,
        optimizer_type=optimizer_type,
        learning_rate=lr,
        task_type='multiclass'
    )

    early_stopping = EarlyStopping(
        monitor='val_f1_macro',
        patience=5,
        mode='max',
    )
    trainer = pl.Trainer(
        max_epochs=max_epochs,
        accelerator='gpu' if torch.cuda.is_available() else 'cpu',
        devices=1,
        callbacks=[early_stopping],
        logger=False,
        enable_progress_bar=False,
        enable_model_summary=False
    )
    trainer.fit(lightning_model, dm)

    metrics = trainer.callback_metrics
    return {
        'val_acc': metrics.get('val_accuracy', 0).item(),
        'val_f1': metrics.get('val_f1_macro', 0).item()
    }

# %%
 # TODO: Обучите итоговую модель с лучшими гиперпараметрами

hidden_dims = [64]
depths = [2]
lrs = [1e-3]
optimizers = ['rmsprop']
combine_modes=['concat']
dropouts = [0.1]
activations = ['relu']
best_val_f1 = 0.0
best_config = None
max_epochs = 100

for hd in hidden_dims:
    for nb in depths:
        for lr in lrs:
            for opt in optimizers:
                for combine_mode in combine_modes:
                    for dropout in dropouts:
                        for activation in activations:
                             model = MultiBranchMLP(
                                 input_dim=dm.input_dim,
                                 hidden_dim=hd,
                                 output_dim=dm.n_classes,
                                 num_blocks=nb,
                                 dropout=dropout,
                                 combine_mode=combine_mode,
                                 activation=activation
                             )
                             metrics = train_model(
                                 model,
                                 dm,
                                 class_weights=class_weights,
                                 max_epochs=max_epochs,
                                 lr=lr,
                                 optimizer_type=opt
                             )
                             val_f1 = metrics['val_f1']
                             val_acc = metrics['val_acc']
                             print(f'hidden_dim={hd}, num_blocks={nb}, lr={lr}, opt={opt} -> val_f1={val_f1:.4f}, val_acc={val_acc:.4f} dropout={dropout:.4f} best_combine_mode={combine_modes} activation={activation}')
                             if val_f1 > best_val_f1:
                                 best_val_f1 = val_f1
                                 best_config = (hd, nb, lr, opt,combine_mode,dropout,activation)

best_hidden_dim, best_depth, best_lr, best_optimizer,best_combine_mode,best_dropout,best_activation = best_config
print(f'Best configuration: hidden_dim={best_hidden_dim}, num_blocks={best_depth}, lr={best_lr}, opt={best_optimizer}, val_f1={best_val_f1:.4f}, best_combine_mode={best_combine_mode}  best_dropout={best_dropout} best_activation={best_activation}')
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Input dimension: 3072
# Number of classes: 10
# Labeled train samples: 1600
# Test samples: 4000
#
# Confusion Matrix:
# [[ 0  0 23  0  0  0  0  0  0  0]
#  [ 0  0 29  0  0  0  1  0  0  0]
#  [ 0  0 24  0  0  0  0  0  1  0]
#  [ 0  0 22  0  0  1  0  0  0  1]
#  [ 0  0 20  0  0  0  0  0  0  0]
#  [ 0  0 26  0  0  1  0  0  1  0]
#  [ 0  0 25  0  0  1  0  0  2  0]
#  [ 0  0 26  0  0  0  0  1  1  0]
#  [ 0  0 27  0  0  0  0  0  1  0]
#  [ 0  0 22  0  0  0  0  0  0  0]]
# Epoch 0: accuracy=0.1055, f1_macro=0.0371
#
# Confusion Matrix:
# [[ 68   0  23   0   0   6   0 307   0   0]
#  [ 94   0  29   0   0  28   1 256   0   0]
#  [ 25   0  24   0   0  27   0 365   1   0]
#  [ 16   0  22   0   0  89   0 320   0   1]
#  [ 19   0  20   0   0  38   0 365   0   0]
#  [ 12   0  26   0   0 100   0 270   1   0]
#  [  5   0  25   0   0  68   0 332   2   0]
#  [ 33   0  26   0   0  27   0 352   1   0]
#  [173   0  27   0   0  18   0 227   1   0]
#  [140   0  22   0   0   7   0 217   0   0]]
# Epoch 0: accuracy=0.1281, f1_macro=0.0661
#
# Confusion Matrix:
# [[ 71 270 116   0   0   6  15 307   0   0]
#  [ 94 271  54   0   0  28  83 256   0   0]
#  [ 25 167 133   0   1  27 140 365   1   0]
#  [ 16 169  88   0   1  89 188 320   0   1]
#  [ 19 118 127   0   1  38 196 365   0   0]
#  [ 12 134 100   0   3 100 170 270   1   0]
#  [  5  94  55   0   0  68 280 332   2   0]
#  [ 33 200  94   0   0  27 143 352   1   0]
#  [173 356  72   0   1  18  16 227   1   0]
#  [140 315  34   0   0   7  37 217   0   0]]
# Epoch 1: accuracy=0.1464, f1_macro=0.1065
#
# Confusion Matrix:
# [[ 71 270 116   0 260   6  15 307 121   0]
#  [ 94 271  54   0 230  28  83 257 147   0]
#  [ 25 167 133   0 367  27 140 365  52   0]
#  [ 16 169  88   0 379  89 188 322  44   1]
#  [ 19 118 127   0 388  38 196 365  35   0]
#  [ 12 134 100   0 361 100 170 270  24   0]
#  [  5  94  55   0 388  68 280 332  18   0]
#  [ 33 200  95   1 320  27 143 352  90   0]
#  [173 356  72   0 161  18  16 227 259   0]
#  [140 315  34   0 148   7  37 217 215   1]]
# Epoch 2: accuracy=0.1514, f1_macro=0.1295
#
# Confusion Matrix:
# [[127 270 116   0 490   6  15 307 208   8]
#  [108 271  54   6 429  28  86 257 234  69]
#  [ 42 168 133   1 724  27 140 365  87   6]
#  [ 31 169  88   3 742  89 192 322  67  17]
#  [ 25 119 127   0 770  38 196 365  60   8]
#  [ 14 134 100   2 712 100 174 270  40   6]
#  [ 10  94  55   2 761  68 287 332  25  10]
#  [ 42 201  95   6 639  27 143 352 150  17]
#  [197 357  72   1 298  18  16 227 482  32]
#  [ 441  594   34    1  339   52  375  536  584  342]]
# Epoch 8: accuracy=0.1686, f1_macro=0.1538
#
# Confusion Matrix:
# [[ 740  520  429    0  608  168  152  668  518   30]
#  [ 331  780  187   14  575  126  575  564  431  227]
#  [ 338  285  457    6 1024  293  710  833  217   32]
#  [ 202  329  358   22 1043  347  903  814  182   64]
#  [ 223  229  435    4 1116  327  887  845  140   34]
#  [ 181  225  355   13 1007  404  802  701  127   23]
#  [  54  209  252    6 1114  312 1217  799   69   36]
#  [ 275  346  386    9  905  244  738  864  294   77]
#  [ 839  810  324    2  365  119  184  576  890   99]
#  [ 441  767  136    5  339   54  388  536  584  412]]
# Epoch 9: accuracy=0.1715, f1_macro=0.1618
#
# Confusion Matrix:
# [[ 740  522  429    0  892  243  152  668  534   34]
#  [ 331  802  187   14  755  262  585  564  434  254]
#  [ 338  286  457    6 1387  338  711  833  219   37]
#  [ 202  330  358   22 1345  462  905  814  183   67]
#  [ 223  230  435    4 1496  363  889  845  141   36]
#  [ 181  226  355   13 1276  508  808  701  127   24]
#  [  54  209  252    6 1451  366 1228  799   69   38]
#  [ 275  346  386    9 1267  286  740  864  295   81]
#  [ 839  828  324    2  567  273  188  576  916  113]
#  [ 441  769  136    5  508  178  391  536  586  476]]
# Epoch 10: accuracy=0.1697, f1_macro=0.1602
#
# Confusion Matrix:
# [[ 740  523  429    0  892  248  152  668  872   71]
#  [ 331  824  187   22  757  272  585  564  596  428]
#  [ 338  288  457   27 1402  384  714  833  506   80]
#  [ 202  336  358   60 1351  525  907  814  411  148]
#  [ 223  240  435   27 1522  443  893  845  375   81]
#  [ 181  229  355   36 1279  588  808  701  344   79]
#  [  54  221  252   41 1461  435 1245  799  232  136]
#  [ 275  357  386   29 1272  349  740  864  527  161]
#  [ 839  829  324    4  567  279  188  576 1254  184]
#  [ 441  778  136    9  509  182  391  536  708  700]]
# Epoch 11: accuracy=0.1710, f1_macro=0.1628
#
# Confusion Matrix:
# [[ 866  523  453    0  892  256  152  823  872  139]
#  [ 344  824  204   22  757  295  586  665  596  651]
#  [ 363  288  483   28 1402  406  714 1143  506  113]
#  [ 212  336  376   60 1351  592  908 1086  411  204]
#  [ 232  240  459   27 1522  462  893 1177  375  119]
#  [ 187  229  382   37 1279  673  808  926  344  116]
#  [  57  221  266   41 1461  474 1247 1094  232  187]
#  [ 283  357  392   29 1272  371  740 1193  527  207]
#  [ 948  829  334    4  567  300  188  693 1254  345]
#  [ 457  778  143    9  509  188  391  616  708  955]]
# Epoch 12: accuracy=0.1737, f1_macro=0.1667
#
# Confusion Matrix:
# [[ 866  541  453    0  892  256  152  921 1137  139]
#  [ 344 1007  204   22  757  295  592  738  705  658]
#  [ 363  306  483   32 1402  406  727 1406  624  114]
#  [ 212  424  376   80 1351  593  919 1309  490  206]
#  [ 232  272  459   30 1522  462  906 1479  446  120]
#  [ 187  294  382   48 1279  673  820 1144  419  116]
#  [  57  279  266   53 1461  474 1305 1333  269  187]
#  [ 283  388  392   31 1272  371  746 1478  612  209]
#  [ 948  869  334    5  567  300  192  731 1586  348]
#  [ 457  885  143   10  509  188  396  700  862  968]]
# Epoch 13: accuracy=0.1772, f1_macro=0.1692
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\ultratb.py:1185, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1183 else:
#    1184     self.tb = etb
# -> 1185 return FormattedTB.structured_traceback(
#    1186     self, etype, evalue, etb, tb_offset, context
#    1187 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\ultratb.py:1056, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1053 mode = self.mode
#    1054 if mode in self.verbose_modes:
#    1055     # Verbose modes need a full traceback
# -> 1056     return VerboseTB.structured_traceback(
#    1057         self, etype, evalue, etb, tb_offset, context
#    1058     )
#    1059 elif mode == "Docs":
#    1060     # return DocTB
#    1061     return DocTB(
#    1062         theme_name=self._theme_name,
#    1063         call_pdb=self.call_pdb,
#    (...)   1071         etype, evalue, etb, tb_offset, 1
#    1072     )  # type: ignore[arg-type]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\ultratb.py:864, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     855 def structured_traceback(
#     856     self,
#     857     etype: type,
#    (...)    861     context: int = 5,
#     862 ) -> list[str]:
#     863     """Return a nice text document describing the traceback."""
# --> 864     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     865         etype, evalue, etb, context, tb_offset
#     866     )
#     868     termsize = min(75, get_terminal_size()[0])
#     869     theme = theme_table[self._theme_name]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\ultratb.py:749, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     747 assert isinstance(tb_offset, int)
#     748 head = self.prepare_header(str(etype), self.long_header)
# --> 749 records = self.get_records(etb, context, tb_offset) if etb else []
#     751 frames = []
#     752 skipped = 0
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\ultratb.py:822, in VerboseTB.get_records(self, etb, context, tb_offset)
#     820 while cf is not None:
#     821     try:
# --> 822         mod = inspect.getmodule(cf.tb_frame)
#     823         if mod is not None:
#     824             mod_name = mod.__name__
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\inspect.py:1022, in getmodule(object, _filename)
#    1020 if ismodule(module) and hasattr(module, '__file__'):
#    1021     f = module.__file__
# -> 1022     if f == _filesbymodname.get(modname, None):
#    1023         # Have already mapped this module, so skip it
#    1024         continue
#    1025     _filesbymodname[modname] = f
#
# KeyboardInterrupt:

# %%
seeds = [22,33,55,11,5,3,4,5,16456,35234,435,112,432]
best_model = None
for seed in seeds:
    set_seed(seed)
    model = MultiBranchMLP(
        input_dim=dm.input_dim,
        hidden_dim=best_hidden_dim,
        output_dim=dm.n_classes,
        num_blocks=best_depth,
        dropout=best_dropout,
        combine_mode=best_combine_mode,
        activation=best_activation
    )
    metrics = train_model(
        model,
        dm,
        class_weights=class_weights,
        max_epochs=max_epochs,
        lr=best_lr,
        optimizer_type=best_optimizer
    )
    val_f1 = metrics['val_f1']
    val_acc = metrics['val_acc']
    print(f'hidden_dim={hd}, num_blocks={nb}, lr={lr}, opt={opt} -> val_f1={val_f1:.4f}, val_acc={val_acc:.4f} dropout={dropout:.4f} best_combine_mode={combine_modes} activation={activation}')
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        best_config = (hd, nb, lr, opt,combine_mode,dropout,activation)
        best_model = model
    if best_val_f1 >= 0.4:
        break
# print(f'=== Итоговые результаты ===')
# print(f"F1 score: {final_results['val_f1']:.4f}")
# print(f"Accuracy: {final_results['val_acc']:.4f}")

print(f'=== Итоговые результаты ===')
print(f'Best configuration: hidden_dim={best_hidden_dim}, num_blocks={best_depth}, lr={best_lr}, opt={best_optimizer}, val_f1={best_val_f1:.4f}, best_combine_mode={best_combine_mode}  best_dropout={best_dropout} best_activation={best_activation}')
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 0: accuracy=0.1133, f1_macro=0.0729
# Epoch 0: accuracy=0.2014, f1_macro=0.1331
# Epoch 1: accuracy=0.2846, f1_macro=0.1932
# Epoch 2: accuracy=0.3117, f1_macro=0.2043
# Epoch 3: accuracy=0.3268, f1_macro=0.2077
# Epoch 4: accuracy=0.3303, f1_macro=0.2093
# Epoch 5: accuracy=0.3451, f1_macro=0.2167
# Epoch 6: accuracy=0.3506, f1_macro=0.2215
# Epoch 7: accuracy=0.3565, f1_macro=0.2245
# Epoch 8: accuracy=0.3619, f1_macro=0.2268
# Epoch 9: accuracy=0.3689, f1_macro=0.2300
# Epoch 10: accuracy=0.3716, f1_macro=0.2321
# Epoch 11: accuracy=0.3748, f1_macro=0.2337
# Epoch 12: accuracy=0.3856, f1_macro=0.2401
# Epoch 13: accuracy=0.3879, f1_macro=0.2411
# Epoch 14: accuracy=0.3946, f1_macro=0.2445
# Epoch 15: accuracy=0.3975, f1_macro=0.2473
# Epoch 16: accuracy=0.4026, f1_macro=0.2499
# Epoch 17: accuracy=0.4069, f1_macro=0.2524
# Epoch 18: accuracy=0.4088, f1_macro=0.2544
# Epoch 19: accuracy=0.4115, f1_macro=0.2563
# Epoch 20: accuracy=0.4151, f1_macro=0.2589
# Epoch 21: accuracy=0.4160, f1_macro=0.2599
# Epoch 22: accuracy=0.4190, f1_macro=0.2620
# Epoch 75: accuracy=0.5058, f1_macro=0.3161
# Epoch 76: accuracy=0.5064, f1_macro=0.3164
# Epoch 77: accuracy=0.5074, f1_macro=0.3170
# Epoch 78: accuracy=0.5085, f1_macro=0.3177
# Epoch 79: accuracy=0.5095, f1_macro=0.3183
# Epoch 80: accuracy=0.5105, f1_macro=0.3190
# Epoch 81: accuracy=0.5119, f1_macro=0.3199
# Epoch 82: accuracy=0.5131, f1_macro=0.3204
# Epoch 83: accuracy=0.5136, f1_macro=0.3207
# Epoch 84: accuracy=0.5146, f1_macro=0.3214
# Epoch 85: accuracy=0.5152, f1_macro=0.3218
# Epoch 86: accuracy=0.5157, f1_macro=0.3220
# Epoch 87: accuracy=0.5166, f1_macro=0.3226
# Epoch 88: accuracy=0.5173, f1_macro=0.3231
# Epoch 89: accuracy=0.5179, f1_macro=0.3235
# Epoch 90: accuracy=0.5184, f1_macro=0.3237
# Epoch 91: accuracy=0.5193, f1_macro=0.3243
# Epoch 92: accuracy=0.5198, f1_macro=0.3245
# Epoch 93: accuracy=0.5205, f1_macro=0.3249
# Epoch 94: accuracy=0.5211, f1_macro=0.3253
# Epoch 95: accuracy=0.5218, f1_macro=0.3256
# Epoch 96: accuracy=0.5228, f1_macro=0.3263
# Epoch 97: accuracy=0.5237, f1_macro=0.3268
# Epoch 98: accuracy=0.5242, f1_macro=0.3272
# Epoch 99: accuracy=0.5250, f1_macro=0.3276
# Epoch 100: accuracy=0.5256, f1_macro=0.3280
# Epoch 101: accuracy=0.5261, f1_macro=0.3283
# Epoch 102: accuracy=0.5270, f1_macro=0.3289
# Epoch 103: accuracy=0.5277, f1_macro=0.3293
# Epoch 104: accuracy=0.5281, f1_macro=0.3295
# Epoch 105: accuracy=0.5289, f1_macro=0.3300
# Epoch 106: accuracy=0.5294, f1_macro=0.3304
# Epoch 107: accuracy=0.5301, f1_macro=0.3308
# Epoch 108: accuracy=0.5305, f1_macro=0.3311
# Epoch 109: accuracy=0.5303, f1_macro=0.3311
# Epoch 110: accuracy=0.5304, f1_macro=0.3312
# Epoch 111: accuracy=0.5306, f1_macro=0.3314
# Epoch 112: accuracy=0.5312, f1_macro=0.3317
# Epoch 113: accuracy=0.5319, f1_macro=0.3321
# Epoch 114: accuracy=0.5325, f1_macro=0.3326
# Epoch 115: accuracy=0.5330, f1_macro=0.3329
# Epoch 116: accuracy=0.5335, f1_macro=0.3331
# Epoch 117: accuracy=0.5338, f1_macro=0.3334
# Epoch 118: accuracy=0.5340, f1_macro=0.3335
# Epoch 119: accuracy=0.5346, f1_macro=0.3338
# Epoch 120: accuracy=0.5349, f1_macro=0.3341
# Epoch 121: accuracy=0.5353, f1_macro=0.3344
# Epoch 122: accuracy=0.5360, f1_macro=0.3348
# Epoch 123: accuracy=0.5366, f1_macro=0.3352
# Epoch 124: accuracy=0.5370, f1_macro=0.3353
# Epoch 125: accuracy=0.5376, f1_macro=0.3356
# Epoch 126: accuracy=0.5378, f1_macro=0.3358
# Epoch 127: accuracy=0.5385, f1_macro=0.3361
# Epoch 494: accuracy=0.5970, f1_macro=0.3761
# Epoch 495: accuracy=0.5971, f1_macro=0.3761
# Epoch 496: accuracy=0.5971, f1_macro=0.3761
# Epoch 497: accuracy=0.5972, f1_macro=0.3762
# Epoch 498: accuracy=0.5973, f1_macro=0.3763
# Epoch 499: accuracy=0.5974, f1_macro=0.3763
# Epoch 500: accuracy=0.5974, f1_macro=0.3764
# Epoch 501: accuracy=0.5975, f1_macro=0.3765
# Epoch 502: accuracy=0.5976, f1_macro=0.3765
# Epoch 503: accuracy=0.5977, f1_macro=0.3766
# Epoch 504: accuracy=0.5977, f1_macro=0.3766
# Epoch 505: accuracy=0.5978, f1_macro=0.3767
# Epoch 506: accuracy=0.5978, f1_macro=0.3767
# Epoch 507: accuracy=0.5979, f1_macro=0.3768
# Epoch 508: accuracy=0.5979, f1_macro=0.3768
# Epoch 509: accuracy=0.5980, f1_macro=0.3768
# Epoch 510: accuracy=0.5980, f1_macro=0.3768
# Epoch 511: accuracy=0.5981, f1_macro=0.3769
# Epoch 512: accuracy=0.5982, f1_macro=0.3769
# Epoch 513: accuracy=0.5982, f1_macro=0.3769
# Epoch 514: accuracy=0.5983, f1_macro=0.3770
# Epoch 515: accuracy=0.5984, f1_macro=0.3770
# Epoch 516: accuracy=0.5984, f1_macro=0.3770
# Epoch 517: accuracy=0.5985, f1_macro=0.3770
# Epoch 518: accuracy=0.5985, f1_macro=0.3770
# Epoch 519: accuracy=0.5985, f1_macro=0.3770
# Epoch 520: accuracy=0.5985, f1_macro=0.3770
# hidden_dim=64, num_blocks=2, lr=0.001, opt=rmsprop -> val_f1=0.3770, val_acc=0.5985 dropout=0.1000 best_combine_mode=['concat'] activation=relu
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 0: accuracy=0.1133, f1_macro=0.1097
# Epoch 0: accuracy=0.2083, f1_macro=0.1445
# Epoch 1: accuracy=0.2712, f1_macro=0.1792
# Epoch 2: accuracy=0.2993, f1_macro=0.1895
# Epoch 3: accuracy=0.3255, f1_macro=0.2020
# Epoch 4: accuracy=0.3421, f1_macro=0.2121
# Epoch 5: accuracy=0.3562, f1_macro=0.2199
# Epoch 6: accuracy=0.3634, f1_macro=0.2231
# Epoch 7: accuracy=0.3761, f1_macro=0.2288
# Epoch 8: accuracy=0.3782, f1_macro=0.2287
# Epoch 9: accuracy=0.3880, f1_macro=0.2351
# Epoch 10: accuracy=0.4002, f1_macro=0.2431
# Epoch 11: accuracy=0.3999, f1_macro=0.2441
# Epoch 12: accuracy=0.4026, f1_macro=0.2454
# Epoch 13: accuracy=0.3984, f1_macro=0.2450
# Epoch 14: accuracy=0.4035, f1_macro=0.2480
# Epoch 15: accuracy=0.4074, f1_macro=0.2506
# Epoch 16: accuracy=0.4117, f1_macro=0.2542
# Epoch 17: accuracy=0.4151, f1_macro=0.2571
# Epoch 18: accuracy=0.4192, f1_macro=0.2599
# Epoch 19: accuracy=0.4228, f1_macro=0.2625
# Epoch 20: accuracy=0.4236, f1_macro=0.2638
# Epoch 74: accuracy=0.5203, f1_macro=0.3231
# Epoch 75: accuracy=0.5212, f1_macro=0.3237
# Epoch 76: accuracy=0.5226, f1_macro=0.3244
# Epoch 77: accuracy=0.5243, f1_macro=0.3253
# Epoch 78: accuracy=0.5256, f1_macro=0.3261
# Epoch 79: accuracy=0.5269, f1_macro=0.3268
# Epoch 80: accuracy=0.5279, f1_macro=0.3274
# Epoch 81: accuracy=0.5288, f1_macro=0.3280
# Epoch 82: accuracy=0.5299, f1_macro=0.3286
# Epoch 83: accuracy=0.5300, f1_macro=0.3285
# Epoch 84: accuracy=0.5310, f1_macro=0.3290
# Epoch 85: accuracy=0.5324, f1_macro=0.3298
# Epoch 86: accuracy=0.5327, f1_macro=0.3300
# Epoch 87: accuracy=0.5340, f1_macro=0.3308
# Epoch 88: accuracy=0.5351, f1_macro=0.3316
# Epoch 89: accuracy=0.5361, f1_macro=0.3322
# Epoch 90: accuracy=0.5373, f1_macro=0.3329
# Epoch 91: accuracy=0.5384, f1_macro=0.3336
# Epoch 92: accuracy=0.5383, f1_macro=0.3336
# Epoch 93: accuracy=0.5394, f1_macro=0.3343
# Epoch 94: accuracy=0.5400, f1_macro=0.3347
# Epoch 95: accuracy=0.5410, f1_macro=0.3354
# Epoch 96: accuracy=0.5421, f1_macro=0.3361
# Epoch 97: accuracy=0.5432, f1_macro=0.3369
# Epoch 98: accuracy=0.5436, f1_macro=0.3372
# Epoch 99: accuracy=0.5441, f1_macro=0.3376
# Epoch 100: accuracy=0.5449, f1_macro=0.3380
# Epoch 101: accuracy=0.5458, f1_macro=0.3386
# Epoch 102: accuracy=0.5468, f1_macro=0.3391
# Epoch 103: accuracy=0.5474, f1_macro=0.3394
# Epoch 104: accuracy=0.5479, f1_macro=0.3398
# Epoch 105: accuracy=0.5485, f1_macro=0.3401
# Epoch 106: accuracy=0.5492, f1_macro=0.3403
# Epoch 107: accuracy=0.5498, f1_macro=0.3407
# Epoch 108: accuracy=0.5505, f1_macro=0.3411
# Epoch 109: accuracy=0.5510, f1_macro=0.3416
# Epoch 110: accuracy=0.5516, f1_macro=0.3420
# Epoch 111: accuracy=0.5520, f1_macro=0.3423
# Epoch 112: accuracy=0.5529, f1_macro=0.3429
# Epoch 113: accuracy=0.5534, f1_macro=0.3432
# Epoch 114: accuracy=0.5539, f1_macro=0.3436
# Epoch 115: accuracy=0.5547, f1_macro=0.3440
# Epoch 116: accuracy=0.5555, f1_macro=0.3445
# Epoch 117: accuracy=0.5561, f1_macro=0.3448
# Epoch 118: accuracy=0.5568, f1_macro=0.3453
# Epoch 119: accuracy=0.5572, f1_macro=0.3456
# Epoch 120: accuracy=0.5576, f1_macro=0.3458
# Epoch 121: accuracy=0.5581, f1_macro=0.3461
# Epoch 122: accuracy=0.5588, f1_macro=0.3466
# Epoch 123: accuracy=0.5593, f1_macro=0.3468
# Epoch 124: accuracy=0.5598, f1_macro=0.3471
# Epoch 125: accuracy=0.5599, f1_macro=0.3474
# Epoch 283: accuracy=0.5970, f1_macro=0.3698
# Epoch 284: accuracy=0.5971, f1_macro=0.3698
# Epoch 285: accuracy=0.5973, f1_macro=0.3699
# Epoch 286: accuracy=0.5974, f1_macro=0.3700
# Epoch 287: accuracy=0.5976, f1_macro=0.3701
# Epoch 288: accuracy=0.5976, f1_macro=0.3701
# Epoch 289: accuracy=0.5977, f1_macro=0.3702
# Epoch 290: accuracy=0.5978, f1_macro=0.3702
# Epoch 291: accuracy=0.5979, f1_macro=0.3702
# Epoch 292: accuracy=0.5980, f1_macro=0.3703
# Epoch 293: accuracy=0.5981, f1_macro=0.3703
# Epoch 294: accuracy=0.5983, f1_macro=0.3703
# Epoch 295: accuracy=0.5984, f1_macro=0.3704
# Epoch 296: accuracy=0.5985, f1_macro=0.3704
# Epoch 297: accuracy=0.5986, f1_macro=0.3705
# Epoch 298: accuracy=0.5987, f1_macro=0.3705
# Epoch 299: accuracy=0.5988, f1_macro=0.3706
# Epoch 300: accuracy=0.5989, f1_macro=0.3707
# Epoch 301: accuracy=0.5990, f1_macro=0.3707
# Epoch 302: accuracy=0.5991, f1_macro=0.3708
# Epoch 303: accuracy=0.5993, f1_macro=0.3709
# Epoch 304: accuracy=0.5994, f1_macro=0.3710
# Epoch 305: accuracy=0.5995, f1_macro=0.3710
# Epoch 306: accuracy=0.5996, f1_macro=0.3711
# Epoch 307: accuracy=0.5998, f1_macro=0.3712
# Epoch 308: accuracy=0.5999, f1_macro=0.3713
# Epoch 309: accuracy=0.6000, f1_macro=0.3714
# Epoch 310: accuracy=0.6001, f1_macro=0.3714
# Epoch 311: accuracy=0.6002, f1_macro=0.3715
# Epoch 312: accuracy=0.6002, f1_macro=0.3715
# Epoch 313: accuracy=0.6002, f1_macro=0.3716
# Epoch 314: accuracy=0.6004, f1_macro=0.3716
# Epoch 315: accuracy=0.6005, f1_macro=0.3717
# Epoch 316: accuracy=0.6006, f1_macro=0.3717
# Epoch 317: accuracy=0.6006, f1_macro=0.3717
# Epoch 318: accuracy=0.6006, f1_macro=0.3717
# Epoch 319: accuracy=0.6006, f1_macro=0.3718
# Epoch 320: accuracy=0.6007, f1_macro=0.3718
# Epoch 321: accuracy=0.6008, f1_macro=0.3718
# Epoch 322: accuracy=0.6009, f1_macro=0.3718
# Epoch 323: accuracy=0.6010, f1_macro=0.3718
# Epoch 324: accuracy=0.6010, f1_macro=0.3718
# Epoch 325: accuracy=0.6011, f1_macro=0.3719
# Epoch 326: accuracy=0.6012, f1_macro=0.3719
# Epoch 327: accuracy=0.6013, f1_macro=0.3720
# Epoch 328: accuracy=0.6014, f1_macro=0.3721
# Epoch 329: accuracy=0.6014, f1_macro=0.3721
# Epoch 330: accuracy=0.6016, f1_macro=0.3722
# Epoch 331: accuracy=0.6017, f1_macro=0.3722
# Epoch 332: accuracy=0.6018, f1_macro=0.3723
# Epoch 333: accuracy=0.6019, f1_macro=0.3723
# Epoch 334: accuracy=0.6019, f1_macro=0.3723
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 439: accuracy=0.6083, f1_macro=0.3751
# hidden_dim=64, num_blocks=2, lr=0.001, opt=rmsprop -> val_f1=0.3751, val_acc=0.6083 dropout=0.1000 best_combine_mode=['concat'] activation=relu
# Epoch 0: accuracy=0.2031, f1_macro=0.1192
# Epoch 0: accuracy=0.1528, f1_macro=0.1208
# Epoch 1: accuracy=0.2009, f1_macro=0.1465
# Epoch 2: accuracy=0.2278, f1_macro=0.1629
# Epoch 3: accuracy=0.2591, f1_macro=0.1776
# Epoch 4: accuracy=0.2834, f1_macro=0.1896
# Epoch 5: accuracy=0.2923, f1_macro=0.1932
# Epoch 6: accuracy=0.2957, f1_macro=0.1953
# Epoch 7: accuracy=0.3097, f1_macro=0.2012
# Epoch 8: accuracy=0.3173, f1_macro=0.2055
# Epoch 9: accuracy=0.3203, f1_macro=0.2074
# Epoch 10: accuracy=0.3273, f1_macro=0.2108
# Epoch 11: accuracy=0.3357, f1_macro=0.2158
# Epoch 12: accuracy=0.3392, f1_macro=0.2187
# Epoch 13: accuracy=0.3457, f1_macro=0.2225
# Epoch 14: accuracy=0.3511, f1_macro=0.2259
# Epoch 15: accuracy=0.3570, f1_macro=0.2291
# Epoch 16: accuracy=0.3639, f1_macro=0.2328
# Epoch 17: accuracy=0.3718, f1_macro=0.2366
# Epoch 18: accuracy=0.3736, f1_macro=0.2386
# Epoch 19: accuracy=0.3810, f1_macro=0.2428
# Epoch 20: accuracy=0.3862, f1_macro=0.2458
# Epoch 21: accuracy=0.3867, f1_macro=0.2464
# Epoch 22: accuracy=0.3933, f1_macro=0.2500
# Epoch 23: accuracy=0.3959, f1_macro=0.2517
# Epoch 24: accuracy=0.4007, f1_macro=0.2543
# Epoch 25: accuracy=0.4038, f1_macro=0.2561
# Epoch 26: accuracy=0.4054, f1_macro=0.2577
# Epoch 27: accuracy=0.4094, f1_macro=0.2601
# Epoch 28: accuracy=0.4114, f1_macro=0.2614
# Epoch 29: accuracy=0.4148, f1_macro=0.2636
# Epoch 30: accuracy=0.4199, f1_macro=0.2663
# Epoch 31: accuracy=0.4203, f1_macro=0.2672
# Epoch 32: accuracy=0.4226, f1_macro=0.2685
# Epoch 33: accuracy=0.4253, f1_macro=0.2698
# Epoch 34: accuracy=0.4283, f1_macro=0.2719
# Epoch 35: accuracy=0.4309, f1_macro=0.2734
# Epoch 36: accuracy=0.4334, f1_macro=0.2745
# Epoch 37: accuracy=0.4356, f1_macro=0.2753
# Epoch 38: accuracy=0.4383, f1_macro=0.2769
# Epoch 39: accuracy=0.4397, f1_macro=0.2780
# Epoch 40: accuracy=0.4404, f1_macro=0.2786
# Epoch 41: accuracy=0.4430, f1_macro=0.2802
# Epoch 42: accuracy=0.4448, f1_macro=0.2816
# Epoch 43: accuracy=0.4473, f1_macro=0.2834
# Epoch 44: accuracy=0.4494, f1_macro=0.2845
# Epoch 45: accuracy=0.4521, f1_macro=0.2861
# Epoch 46: accuracy=0.4547, f1_macro=0.2875
# Epoch 47: accuracy=0.4563, f1_macro=0.2885
# Epoch 48: accuracy=0.4575, f1_macro=0.2894
# Epoch 101: accuracy=0.5192, f1_macro=0.3230
# Epoch 102: accuracy=0.5200, f1_macro=0.3234
# Epoch 103: accuracy=0.5208, f1_macro=0.3239
# Epoch 104: accuracy=0.5215, f1_macro=0.3243
# ...
# Epoch 160: accuracy=0.5684, f1_macro=0.3581
# Epoch 161: accuracy=0.5688, f1_macro=0.3583
# Epoch 162: accuracy=0.5691, f1_macro=0.3585
# Epoch 163: accuracy=0.5686, f1_macro=0.3584
# Epoch 164: accuracy=0.5692, f1_macro=0.3588
# Epoch 165: accuracy=0.5699, f1_macro=0.3593
# Epoch 166: accuracy=0.5706, f1_macro=0.3598
# Epoch 167: accuracy=0.5709, f1_macro=0.3600
# Epoch 168: accuracy=0.5714, f1_macro=0.3603
# Epoch 169: accuracy=0.5719, f1_macro=0.3607
# Epoch 170: accuracy=0.5725, f1_macro=0.3612
# Epoch 171: accuracy=0.5730, f1_macro=0.3615
# Epoch 172: accuracy=0.5731, f1_macro=0.3616
# Epoch 173: accuracy=0.5737, f1_macro=0.3620
# Epoch 174: accuracy=0.5741, f1_macro=0.3623
# Epoch 175: accuracy=0.5745, f1_macro=0.3626
# Epoch 176: accuracy=0.5749, f1_macro=0.3629
# Epoch 177: accuracy=0.5755, f1_macro=0.3633
# Epoch 178: accuracy=0.5757, f1_macro=0.3636
# Epoch 179: accuracy=0.5762, f1_macro=0.3640
# Epoch 180: accuracy=0.5768, f1_macro=0.3644
# Epoch 181: accuracy=0.5773, f1_macro=0.3647
# Epoch 182: accuracy=0.5777, f1_macro=0.3651
# Epoch 183: accuracy=0.5780, f1_macro=0.3653
# Epoch 184: accuracy=0.5784, f1_macro=0.3656
# Epoch 185: accuracy=0.5787, f1_macro=0.3658
# Epoch 186: accuracy=0.5792, f1_macro=0.3661
# Epoch 187: accuracy=0.5797, f1_macro=0.3665
# Epoch 188: accuracy=0.5802, f1_macro=0.3669
# Epoch 189: accuracy=0.5807, f1_macro=0.3672
# Epoch 190: accuracy=0.5808, f1_macro=0.3674
# Epoch 191: accuracy=0.5813, f1_macro=0.3677
# Epoch 192: accuracy=0.5818, f1_macro=0.3681
# Epoch 193: accuracy=0.5822, f1_macro=0.3684
# Epoch 194: accuracy=0.5828, f1_macro=0.3688
# Epoch 195: accuracy=0.5832, f1_macro=0.3691
# Epoch 196: accuracy=0.5837, f1_macro=0.3695
# Epoch 197: accuracy=0.5840, f1_macro=0.3697
# Epoch 198: accuracy=0.5841, f1_macro=0.3699
# Epoch 199: accuracy=0.5844, f1_macro=0.3701
# Epoch 200: accuracy=0.5848, f1_macro=0.3704
# Epoch 201: accuracy=0.5851, f1_macro=0.3706
# Epoch 202: accuracy=0.5856, f1_macro=0.3710
# Epoch 203: accuracy=0.5861, f1_macro=0.3713
# Epoch 204: accuracy=0.5865, f1_macro=0.3715
# Epoch 205: accuracy=0.5869, f1_macro=0.3718
# Epoch 206: accuracy=0.5874, f1_macro=0.3722
# Epoch 207: accuracy=0.5878, f1_macro=0.3725
# Epoch 260: accuracy=0.6023, f1_macro=0.3838
# Epoch 261: accuracy=0.6025, f1_macro=0.3840
# Epoch 262: accuracy=0.6028, f1_macro=0.3842
# Epoch 263: accuracy=0.6031, f1_macro=0.3844
# Epoch 264: accuracy=0.6032, f1_macro=0.3845
# Epoch 265: accuracy=0.6034, f1_macro=0.3846
# Epoch 266: accuracy=0.6036, f1_macro=0.3847
# Epoch 267: accuracy=0.6039, f1_macro=0.3849
# Epoch 268: accuracy=0.6041, f1_macro=0.3850
# Epoch 269: accuracy=0.6044, f1_macro=0.3852
# Epoch 270: accuracy=0.6046, f1_macro=0.3853
# Epoch 271: accuracy=0.6048, f1_macro=0.3854
# Epoch 272: accuracy=0.6051, f1_macro=0.3856
# Epoch 273: accuracy=0.6052, f1_macro=0.3858
# Epoch 274: accuracy=0.6054, f1_macro=0.3859
# Epoch 275: accuracy=0.6057, f1_macro=0.3860
# Epoch 276: accuracy=0.6060, f1_macro=0.3862
# Epoch 277: accuracy=0.6062, f1_macro=0.3864
# Epoch 278: accuracy=0.6064, f1_macro=0.3866
# Epoch 279: accuracy=0.6067, f1_macro=0.3867
# Epoch 280: accuracy=0.6069, f1_macro=0.3869
# Epoch 281: accuracy=0.6072, f1_macro=0.3871
# Epoch 282: accuracy=0.6074, f1_macro=0.3872
# Epoch 283: accuracy=0.6075, f1_macro=0.3872
# Epoch 284: accuracy=0.6076, f1_macro=0.3873
# Epoch 285: accuracy=0.6079, f1_macro=0.3874
# Epoch 286: accuracy=0.6081, f1_macro=0.3875
# Epoch 287: accuracy=0.6082, f1_macro=0.3876
# Epoch 288: accuracy=0.6084, f1_macro=0.3877
# Epoch 289: accuracy=0.6086, f1_macro=0.3879
# Epoch 290: accuracy=0.6087, f1_macro=0.3880
# Epoch 291: accuracy=0.6089, f1_macro=0.3881
# Epoch 292: accuracy=0.6091, f1_macro=0.3882
# Epoch 293: accuracy=0.6094, f1_macro=0.3884
# Epoch 294: accuracy=0.6097, f1_macro=0.3886
# Epoch 295: accuracy=0.6099, f1_macro=0.3887
# Epoch 296: accuracy=0.6101, f1_macro=0.3889
# Epoch 297: accuracy=0.6103, f1_macro=0.3890
# Epoch 298: accuracy=0.6105, f1_macro=0.3892
# Epoch 299: accuracy=0.6107, f1_macro=0.3893
# Epoch 300: accuracy=0.6109, f1_macro=0.3894
# Epoch 301: accuracy=0.6110, f1_macro=0.3896
# Epoch 302: accuracy=0.6112, f1_macro=0.3897
# Epoch 303: accuracy=0.6113, f1_macro=0.3898
# Epoch 304: accuracy=0.6114, f1_macro=0.3899
# Epoch 305: accuracy=0.6116, f1_macro=0.3900
# Epoch 306: accuracy=0.6118, f1_macro=0.3901
# Epoch 307: accuracy=0.6119, f1_macro=0.3903
# Epoch 308: accuracy=0.6121, f1_macro=0.3904
# Epoch 309: accuracy=0.6123, f1_macro=0.3905
# Epoch 310: accuracy=0.6124, f1_macro=0.3906
# Epoch 311: accuracy=0.6126, f1_macro=0.3907
# Epoch 312: accuracy=0.6129, f1_macro=0.3909
# Epoch 365: accuracy=0.6199, f1_macro=0.3967
# Epoch 366: accuracy=0.6200, f1_macro=0.3967
# Epoch 367: accuracy=0.6202, f1_macro=0.3968
# Epoch 368: accuracy=0.6203, f1_macro=0.3969
# Epoch 369: accuracy=0.6203, f1_macro=0.3970
# Epoch 370: accuracy=0.6204, f1_macro=0.3970
# Epoch 371: accuracy=0.6205, f1_macro=0.3971
# Epoch 372: accuracy=0.6206, f1_macro=0.3972
# Epoch 373: accuracy=0.6207, f1_macro=0.3973
# Epoch 374: accuracy=0.6208, f1_macro=0.3974
# Epoch 375: accuracy=0.6210, f1_macro=0.3975
# Epoch 376: accuracy=0.6211, f1_macro=0.3976
# Epoch 377: accuracy=0.6212, f1_macro=0.3977
# Epoch 378: accuracy=0.6213, f1_macro=0.3978
# Epoch 379: accuracy=0.6215, f1_macro=0.3979
# Epoch 380: accuracy=0.6216, f1_macro=0.3980
# Epoch 381: accuracy=0.6217, f1_macro=0.3981
# Epoch 382: accuracy=0.6218, f1_macro=0.3982
# Epoch 383: accuracy=0.6218, f1_macro=0.3983
# Epoch 384: accuracy=0.6219, f1_macro=0.3984
# Epoch 385: accuracy=0.6220, f1_macro=0.3984
# Epoch 386: accuracy=0.6222, f1_macro=0.3985
# Epoch 387: accuracy=0.6222, f1_macro=0.3986
# Epoch 388: accuracy=0.6223, f1_macro=0.3987
# Epoch 389: accuracy=0.6223, f1_macro=0.3987
# Epoch 390: accuracy=0.6224, f1_macro=0.3988
# Epoch 391: accuracy=0.6225, f1_macro=0.3988
# Epoch 392: accuracy=0.6226, f1_macro=0.3989
# Epoch 393: accuracy=0.6227, f1_macro=0.3990
# Epoch 394: accuracy=0.6226, f1_macro=0.3989
# Epoch 395: accuracy=0.6225, f1_macro=0.3988
# Epoch 396: accuracy=0.6225, f1_macro=0.3989
# Epoch 397: accuracy=0.6226, f1_macro=0.3989
# Epoch 398: accuracy=0.6227, f1_macro=0.3990
# Epoch 399: accuracy=0.6227, f1_macro=0.3991
# Epoch 400: accuracy=0.6228, f1_macro=0.3991
# Epoch 401: accuracy=0.6229, f1_macro=0.3992
# Epoch 402: accuracy=0.6229, f1_macro=0.3992
# Epoch 403: accuracy=0.6230, f1_macro=0.3993
# Epoch 404: accuracy=0.6231, f1_macro=0.3994
# Epoch 405: accuracy=0.6231, f1_macro=0.3994
# Epoch 406: accuracy=0.6232, f1_macro=0.3995
# Epoch 407: accuracy=0.6233, f1_macro=0.3995
# Epoch 408: accuracy=0.6234, f1_macro=0.3996
# Epoch 409: accuracy=0.6235, f1_macro=0.3997
# Epoch 410: accuracy=0.6235, f1_macro=0.3998
# Epoch 411: accuracy=0.6236, f1_macro=0.3998
# Epoch 412: accuracy=0.6237, f1_macro=0.3999
# Epoch 413: accuracy=0.6238, f1_macro=0.3999
# Epoch 414: accuracy=0.6238, f1_macro=0.4000
# Epoch 415: accuracy=0.6240, f1_macro=0.4001
# Epoch 416: accuracy=0.6240, f1_macro=0.4001
# Epoch 417: accuracy=0.6241, f1_macro=0.4002
# Epoch 418: accuracy=0.6243, f1_macro=0.4003
# Epoch 419: accuracy=0.6243, f1_macro=0.4004
# Epoch 420: accuracy=0.6244, f1_macro=0.4004
# Epoch 421: accuracy=0.6246, f1_macro=0.4005
# Epoch 422: accuracy=0.6247, f1_macro=0.4006
# Epoch 423: accuracy=0.6247, f1_macro=0.4006
# Epoch 424: accuracy=0.6248, f1_macro=0.4007
# Epoch 425: accuracy=0.6249, f1_macro=0.4008
# Epoch 426: accuracy=0.6249, f1_macro=0.4009
# Epoch 427: accuracy=0.6250, f1_macro=0.4009
# Epoch 428: accuracy=0.6251, f1_macro=0.4010
# Epoch 429: accuracy=0.6252, f1_macro=0.4010
# Epoch 430: accuracy=0.6252, f1_macro=0.4011
# Epoch 431: accuracy=0.6253, f1_macro=0.4012
# Epoch 432: accuracy=0.6254, f1_macro=0.4013
# Epoch 433: accuracy=0.6255, f1_macro=0.4014
# Epoch 434: accuracy=0.6256, f1_macro=0.4014
# Epoch 435: accuracy=0.6257, f1_macro=0.4015
# Epoch 436: accuracy=0.6257, f1_macro=0.4015
# Epoch 437: accuracy=0.6258, f1_macro=0.4016
# Epoch 438: accuracy=0.6259, f1_macro=0.4016
# Epoch 439: accuracy=0.6260, f1_macro=0.4017
# Epoch 440: accuracy=0.6260, f1_macro=0.4017
# Epoch 441: accuracy=0.6261, f1_macro=0.4018
# Epoch 442: accuracy=0.6261, f1_macro=0.4018
# Epoch 443: accuracy=0.6262, f1_macro=0.4019
# Epoch 444: accuracy=0.6263, f1_macro=0.4019
# Epoch 445: accuracy=0.6263, f1_macro=0.4020
# Epoch 446: accuracy=0.6264, f1_macro=0.4021
# Epoch 447: accuracy=0.6265, f1_macro=0.4021
# Epoch 448: accuracy=0.6266, f1_macro=0.4022
# Epoch 449: accuracy=0.6267, f1_macro=0.4023
# Epoch 450: accuracy=0.6268, f1_macro=0.4023
# Epoch 451: accuracy=0.6268, f1_macro=0.4024
# Epoch 452: accuracy=0.6269, f1_macro=0.4024
# Epoch 453: accuracy=0.6268, f1_macro=0.4023
# Epoch 454: accuracy=0.6269, f1_macro=0.4024
# Epoch 455: accuracy=0.6269, f1_macro=0.4024
# Epoch 456: accuracy=0.6270, f1_macro=0.4025
# Epoch 457: accuracy=0.6271, f1_macro=0.4025
# Epoch 458: accuracy=0.6271, f1_macro=0.4026
# Epoch 459: accuracy=0.6272, f1_macro=0.4026
# Epoch 460: accuracy=0.6273, f1_macro=0.4027
# Epoch 461: accuracy=0.6274, f1_macro=0.4028
# Epoch 462: accuracy=0.6275, f1_macro=0.4028
# Epoch 463: accuracy=0.6276, f1_macro=0.4028
# Epoch 464: accuracy=0.6277, f1_macro=0.4029
# Epoch 465: accuracy=0.6277, f1_macro=0.4030
# Epoch 466: accuracy=0.6278, f1_macro=0.4030
# Epoch 467: accuracy=0.6279, f1_macro=0.4031
# Epoch 468: accuracy=0.6279, f1_macro=0.4031
# Epoch 469: accuracy=0.6280, f1_macro=0.4032
# Epoch 470: accuracy=0.6281, f1_macro=0.4032
# Epoch 471: accuracy=0.6281, f1_macro=0.4033
# Epoch 472: accuracy=0.6282, f1_macro=0.4033
# Epoch 473: accuracy=0.6282, f1_macro=0.4033
# Epoch 474: accuracy=0.6282, f1_macro=0.4033
# Epoch 475: accuracy=0.6282, f1_macro=0.4033
# Epoch 476: accuracy=0.6283, f1_macro=0.4033
# Epoch 477: accuracy=0.6283, f1_macro=0.4033
# Epoch 478: accuracy=0.6284, f1_macro=0.4034
# Epoch 479: accuracy=0.6284, f1_macro=0.4035
# Epoch 480: accuracy=0.6285, f1_macro=0.4035
# Epoch 481: accuracy=0.6285, f1_macro=0.4035
# Epoch 482: accuracy=0.6285, f1_macro=0.4035
# Epoch 483: accuracy=0.6286, f1_macro=0.4035
# Epoch 484: accuracy=0.6286, f1_macro=0.4035
# Epoch 485: accuracy=0.6287, f1_macro=0.4036
# Epoch 486: accuracy=0.6288, f1_macro=0.4036
# Epoch 487: accuracy=0.6289, f1_macro=0.4037
# Epoch 488: accuracy=0.6289, f1_macro=0.4038
# Epoch 489: accuracy=0.6290, f1_macro=0.4038
# Epoch 490: accuracy=0.6291, f1_macro=0.4038
# Epoch 491: accuracy=0.6291, f1_macro=0.4039
# Epoch 492: accuracy=0.6292, f1_macro=0.4039
# Epoch 493: accuracy=0.6292, f1_macro=0.4040
# Epoch 494: accuracy=0.6292, f1_macro=0.4040
# Epoch 495: accuracy=0.6293, f1_macro=0.4040
# Epoch 496: accuracy=0.6294, f1_macro=0.4040
# Epoch 497: accuracy=0.6294, f1_macro=0.4041
# Epoch 498: accuracy=0.6295, f1_macro=0.4041
# Epoch 499: accuracy=0.6296, f1_macro=0.4041
# Epoch 500: accuracy=0.6296, f1_macro=0.4042
# Epoch 501: accuracy=0.6297, f1_macro=0.4042
# Epoch 502: accuracy=0.6298, f1_macro=0.4043
# Epoch 503: accuracy=0.6299, f1_macro=0.4044
# Epoch 504: accuracy=0.6299, f1_macro=0.4044
# Epoch 505: accuracy=0.6300, f1_macro=0.4044
# Epoch 506: accuracy=0.6300, f1_macro=0.4045
# Epoch 507: accuracy=0.6300, f1_macro=0.4045
# Epoch 508: accuracy=0.6301, f1_macro=0.4045
# Epoch 509: accuracy=0.6301, f1_macro=0.4046
# Epoch 510: accuracy=0.6302, f1_macro=0.4046
# Epoch 511: accuracy=0.6302, f1_macro=0.4046
# Epoch 512: accuracy=0.6302, f1_macro=0.4045
# Epoch 513: accuracy=0.6302, f1_macro=0.4045
# Epoch 514: accuracy=0.6303, f1_macro=0.4046
# Epoch 515: accuracy=0.6304, f1_macro=0.4046
# hidden_dim=64, num_blocks=2, lr=0.001, opt=rmsprop -> val_f1=0.4046, val_acc=0.6304 dropout=0.1000 best_combine_mode=['concat'] activation=relu
# === Итоговые результаты ===
# Best configuration: hidden_dim=64, num_blocks=2, lr=0.001, opt=rmsprop, val_f1=0.4046, best_combine_mode=concat  best_dropout=0.1 best_activation=relu
